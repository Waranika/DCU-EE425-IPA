# %% [markdown]
# <a href="https://colab.research.google.com/github/Waranika/DCU-EE425-IPA/blob/main/Assignement/Part1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from skimage import data,io,filters
from matplotlib import pyplot as plt
from skimage.color import rgb2gray
from skimage.transform import resize
from skimage.util import random_noise
from skimage.filters.rank import mean
from skimage.morphology import square
from skimage.filters.rank import median
from skimage.filters import gaussian

import numpy as np

# %% [markdown]
# a) Import and resize to 512 x 512  an image of your face. Then convert it to greyscale and display the minimum, maximum and mean grayscale values

# %%
#Import the image
image = io.imread("face.jpg")
#Resize image
image = resize(image, (512, 512))
#Greyscale it
grey_image = rgb2gray(image)

# %%
print("The greyscale minimum value is", grey_image.min(), "The greyscale maximum value is ", grey_image.max(), "The greyscale mean value is ", grey_image.mean())
# Out:
# The greyscale minimum value is 0.02059983244234583 The greyscale maximum value is  0.9383496307440385 The greyscale mean value is  0.46378199902220973

# %%
fig, ax = plt.subplots(1, 2 )
ax[0] = plt.subplot(1, 2, 1)
ax[1] = plt.subplot(1, 2, 2)

ax[0].imshow(image, cmap = plt.cm.gray)
ax[1].imshow(grey_image, cmap = plt.cm.gray)

# %% [markdown]
# b) Taking the output image from part (a) and add Gaussian noise (mean=0.0, variance=0.01). Display your result.

# %%
noised_image = random_noise(grey_image, mode='gaussian', mean=0.0, var=0.01)

# %%
fig, ax = plt.subplots(1, 2 )
ax[0] = plt.subplot(1, 2, 1)
ax[1] = plt.subplot(1, 2, 2)

ax[0].imshow(grey_image, cmap = plt.cm.gray)
ax[1].imshow(noised_image, cmap = plt.cm.gray)

# %%
mean = mean(noised_image, square(5))
# Out:
# <ipython-input-148-ac841258d082>:1: UserWarning: Possible precision loss converting image of type float64 to uint8 as required by rank filters. Convert manually using skimage.util.img_as_ubyte to silence this warning.
#   mean = mean(noised_image, square(5))

# %%
filtered = median(noised_image, square(5))
# Out:
# <ipython-input-149-47647188be21>:1: UserWarning: Possible precision loss converting image of type float64 to uint8 as required by rank filters. Convert manually using skimage.util.img_as_ubyte to silence this warning.
#   filtered = median(noised_image, square(5))

# %%
if mean.all() == noised_image.all():
  print("similar")

# %%
fig, ax = plt.subplots(1, 3 )
ax[0] = plt.subplot(1, 3, 1)
ax[1] = plt.subplot(1, 3, 2)
ax[2] = plt.subplot(1, 3, 3)
ax[0].imshow(noised_image, cmap = plt.cm.gray)
ax[1].imshow(mean, cmap = plt.cm.gray)
ax[2].imshow(filtered, cmap = plt.cm.gray)

# %%
gauss_img = gaussian(noised_image, sigma = 1)
gauss_img2 = gaussian(noised_image, sigma = 0.1)
gauss_img3 = gaussian(noised_image, sigma = 2)

fig, ax = plt.subplots(1, 3 )
ax[0] = plt.subplot(1, 3, 1)
ax[1] = plt.subplot(1, 3, 2)
ax[2] = plt.subplot(1, 3, 3)
ax[0].imshow(gauss_img, cmap = plt.cm.gray)
ax[1].imshow(gauss_img2, cmap = plt.cm.gray)
ax[2].imshow(gauss_img3, cmap = plt.cm.gray)

# %%
ax = plt.hist(grey_image.ravel(), bins = 256)
plt.show()

# %%
ax = plt.hist(gauss_img2.ravel(), bins = 256)
plt.show()
