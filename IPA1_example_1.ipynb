# %%
from google.colab import drive, files
import os
from skimage import data,io,filters
from matplotlib import pyplot as plt
from skimage.color import rgb2gray

# %%
image = io.imread("birds.jpg")

# %%
grey_image = rgb2gray(image)

# %%
print(image.shape)
# Out:
# (171, 294, 3)

# %%
io.imshow(image)

# %%
io.imshow(grey_image)

# %%
print(grey_image.shape)
# Out:
# (171, 294)

# %%
print(grey_image.min(),grey_image.max(),grey_image.mean())
# Out:
# 0.0 0.9980356862745098 0.5599948836454659

# %%
fig, ax = plt.subplots(1, 2, figsize=(30, 10))
ax[0] = plt.subplot(1, 2, 1)
ax[1] = plt.subplot(1, 2, 2)
# subplot(number of row, number of colum, number of image)
ax[0].imshow(image, cmap = plt.cm.gray)
ax[1].imshow(grey_image, cmap = plt.cm.gray)
#Need to add gray color map
